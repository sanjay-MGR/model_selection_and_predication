# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjay-MGR/model_selection_and_predication/blob/main/Predict_the_mpg_using_the_save_model_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import laiberis
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import joblib

# %%
from google.colab import files

# %%
upload = files.upload()
# Out:
#      <input type="file" id="files-6eec4871-8b88-4dcb-82ec-94b387b4847f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6eec4871-8b88-4dcb-82ec-94b387b4847f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
model = joblib.load('/content/forest_model.pkl')

# %%
model
# Out:
# RandomForestRegressor()

# %%
upload = files.upload()
# Out:
#      <input type="file" id="files-e76d709b-d1ac-40e8-98bb-13013473f354" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e76d709b-d1ac-40e8-98bb-13013473f354">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv(r"/content/expanded_1000_rows.csv")

# %%
data.head(2)
# Out:
#    Unnamed: 0  cylinders  displacement  horsepower  weight  acceleration
# 0           0          8         307.0       130.0    3504          12.0
# 1           1          8         350.0       165.0    3693          11.5

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration'],
#       dtype='object')

# %%
data= data.drop('Unnamed: 0',axis = 1)

# %%
data.head(4)
# Out:
#    cylinders  displacement  horsepower  weight  acceleration
# 0          8         307.0       130.0    3504          12.0
# 1          8         350.0       165.0    3693          11.5
# 2          8         318.0       150.0    3436          11.0
# 3          8         304.0       150.0    3433          12.0

# %%
#make a predication
mpg_output = model.predict(data)

# %%
mpg_output
# Out:
# array([17.018     , 15.1515    , 16.99      , 16.23514286, 17.064     ,
#        14.204     , 14.026     , 14.03      , 13.455     , 14.06      ,
#        15.226     , 14.511     , 14.825     , 14.682     , 24.694     ,
#        19.254     , 18.865     , 21.184     , 27.225     , 28.309     ,
#        26.028     , 26.976     , 24.857     , 26.065     , 20.62      ,
#        11.629     , 11.198     , 12.283     ,  9.895     , 27.225     ,
#        25.317     , 25.286     , 24.989     , 21.674     , 16.82      ,
#        17.685     , 18.726     , 18.612     , 14.154     , 14.155     ,
#        14.225     , 14.405     , 12.79      , 12.94      , 12.66      ,
#        21.655     , 24.931     , 18.959     , 18.594     , 24.133     ,
#        26.902     , 32.284     , 30.513     , 32.13      , 34.449     ,
#        32.2       , 33.118     , 25.975     , 26.837     , 25.763     ,
#        21.779     , 22.059     , 13.681     , 13.885     , 14.89      ,
# ...

# %%
output_mpg = pd.DataFrame(mpg_output,columns = ['output_mpg'])

# %%
output_mpg
# Out:
#      output_mpg
# 0     17.018000
# 1     15.151500
# 2     16.990000
# 3     16.235143
# 4     17.064000
# ..          ...
# 995   19.422000
# 996   18.534000
# 997   18.268000
# 998   17.734000
# 999   31.420000
#
# [1000 rows x 1 columns]

# %%
#save the output
output_mpg.to_csv('output_mpg.csv')

# %%
#put the output into the Dataset
data['output_mpg']=mpg_output

# %%
data.head(2)
# Out:
#    cylinders  displacement  horsepower  weight  acceleration  output_mpg
# 0          8         307.0       130.0    3504          12.0     17.0180
# 1          8         350.0       165.0    3693          11.5     15.1515

# %%
#save the input output
data.to_csv('input with predicted ')
